# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 기존 신경망과 CNN의 Parameter 수 비교
# * 기존은 입력 이미지가 Parameter 크기에 직접 영향을 미쳤으나, CNN은 훨씬 작은 Kernel 크기가 영향을 준다.
#
#   단, 은닉층의 갯수에 의한 비례 증가는 동일.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Feature Map 크기

# %% [markdown]
# * Input Size : $I_h$ x $I_w$ ,  Kernel Size : $K_h$ x $K_w$,  Stride : S,  Pading : P
#
#   Feature Map Size : $\frac{(I_h - K_h + 2P +S)}{S}$ x $\frac{(I_w - K_w + 2P +S)}{S}$

# %% [markdown]
# # Channel 수
#
# * k 개 Channel의 Input에는 k Channel의 1개 Kernel이 필요하고, Output인 Feature mape은 1개의 Channel을 가진다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 따라서 Feature Map의 Channel 수는 Kernel 갯수로 결정된다.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Pooling
# * 특성 맵을 다운샘플링하여 특성 맵의 크기를 줄이는 연산

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Pooling 연산에도 Kernel과 Stride가 필요하나, 학습해야하는 가중치가 없고, Channel 수가 유지됨.
# * Pooling에는 위 그림처럼 최대값을 추출하는 max pooling과 평균값을 추출하는 average pooling이 있음.

# %% [markdown]
# # Subsampling (downsampling)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Convolutional 층과 subsample 층 교대로 반복됨.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Input Image에 Convolution 과정을 수행하는 것은 단지 수치적 연산이다. 이 numerical result에 Pooling을 하는 것은 특성 추출 과정인데, linear Model과 Activation Function을 통해 확률값(probabilities)으로 변환한 것이 바로 subsample이다.
#
# * 따라서 Convolution 층은 numerical matrices인 반면, Subsample은 항상 featured pictures이다

# %% [markdown]
# * References
#
#   - https://ireneli.eu/2016/02/03/deep-learning-05-talk-about-convolutional-neural-network%EF%BC%88cnn%EF%BC%89/
#   - https://wikidocs.net/62306
